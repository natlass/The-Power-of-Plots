# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sts
from scipy.stats import sem
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")

# Display the data table for preview
combined_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
total_df = len(combined_df['Mouse ID'].unique())
total_df
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dupl = combined_df[combined_df.duplicated(['Mouse ID', 'Timepoint'])]
dupl
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate = combined_df[combined_df.duplicated()] 
  
print("Duplicate Rows :") 
  
# Print the resultant Dataframe 
duplicate
# Out:
# Duplicate Rows :
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909                45.0                 0

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = combined_df.loc[combined_df['Mouse ID']!='g989']
clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
new_total_df = len(clean_df['Mouse ID'].unique())
new_total_df
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
new_df = clean_df[['Drug Regimen', 'Tumor Volume (mm3)']]
new_df = clean_df.groupby('Drug Regimen')
index = new_df.mean().index

mean = (new_df['Tumor Volume (mm3)']).mean().values
median = (new_df['Tumor Volume (mm3)']).median().values
var = (new_df['Tumor Volume (mm3)']).var().values
sd = (new_df['Tumor Volume (mm3)']).std().values
sem = (new_df['Tumor Volume (mm3)']).sem().values
      
summary_df = pd.DataFrame({"Mean": mean,
                          "Median": median,
                          "Variance": var,
                           "Standard Dev.": sd,
                          "SEM": sem}, index = index)
summary_df
# Out:
#                    Mean     Median   Variance  Standard Dev.       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764       4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177       6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684       6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577       8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479       8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083       7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013       6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704       4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562       7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355       6.966589  0.516398

# %%
# Using the aggregation method, produce the same summary statistics in a single line
new2_df = clean_df.groupby('Drug Regimen').agg({'Tumor Volume (mm3)': ["mean","median","var","std","sem"]})
new2_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.

drug = clean_df['Drug Regimen'].value_counts().plot(kind="bar")
plt.title("Total Number of Mice Tested on Each Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Total Number Mice Tested")
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.

drug = clean_df['Drug Regimen'].value_counts()
plt.bar(drug.index, drug.values)
plt.title("Total Number of Mice Tested on Each Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Total Number Mice Tested")
plt.tight_layout()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# Create the pie plot using a value counts of the dataframe
color= ['lightblue', 'pink']
sex = clean_df['Sex'].value_counts().plot(kind="pie", colors=color, title = "Distribution of Female vs. Male mice (pandas)", autopct="%1.1f%%", startangle=140)

# Extra formatting
plt.title = ("Distribution of Female vs. Male mice (pandas)")

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# Create data containing the sex of the mice
sex = clean_df['Sex'].value_counts()

# Create your pie plot, include formatting
plt.pie(sex.values, colors=color, labels=sex.index, autopct="%1.1f%%", startangle=140)
title=("Distribution of Female vs. Male Mice (pyplot)")
color = ['lightblue', 'pink']

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
last_timepoint_df = clean_df.groupby('Mouse ID')['Timepoint'].max()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

tumor_volume_df = pd.merge(last_timepoint_df, clean_df, how='inner', left_on=['Mouse ID', 'Timepoint'], right_on=['Mouse ID', 'Timepoint'])

# %%
# Put treatments into a list for for loop (and later for plot labels)
drug_list = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
for treatment in drug_list:
    tum_vol = []
    for index, row in tumor_volume_df.iterrows():
        if row[2] == treatment:
            tum_vol.append(row[6])
            
    tumor = pd.Series(tum_vol)

    # Calculate the IQR and quantitatively determine if there are any potential outliers. 
    quartiles = tumor.quantile([.25, .5, .75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    step = 1.5
    
    lower_bound = lowerq - (step*iqr)
    upper_bound = upperq + (step*iqr)
    
    for item in tumor.iteritems():
        if item[1] < lower_bound:
            print(f'{item[1]} is an outlier in the {treatment} sample.')
        elif item[1] > upper_bound:
            print(f'{item[1]} is an outlier in the {treatment} sample.')
# Out:
# 36.321345799999996 is an outlier in the Infubinol sample.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
Capomulin_df = tumor_volume_df.loc[tumor_volume_df['Drug Regimen'] == 'Capomulin']
Ramicane_df = tumor_volume_df.loc[tumor_volume_df['Drug Regimen'] == 'Ramicane']
Infubinol_df = tumor_volume_df.loc[tumor_volume_df['Drug Regimen'] == 'Infubinol']
Ceftamin_df = tumor_volume_df.loc[tumor_volume_df['Drug Regimen'] == 'Ceftamin']

# create a list of tumor volumes series for eaach regimen
drugg = [Capomulin_df['Tumor Volume (mm3)']
        ,Ramicane_df['Tumor Volume (mm3)']
        ,Infubinol_df['Tumor Volume (mm3)']
        ,Ceftamin_df['Tumor Volume (mm3)']
       ]

fig, ax1 = plt.subplots()

x_axis = np.arange(len(drug_list))
tick_locations = [value+1 for value in x_axis]
plt.xticks(drug_list)
ax1.set_title('Final Tumor Volume')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.set_xlabel('Drug Regimens')
ax1.boxplot(drugg)

plt.grid()
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# Generate a capomuin only dataframe to pull data from
capomulin_df = clean_df.loc[clean_df['Drug Regimen'] == 'Capomulin']

# Grab your random capomulin treated mouse
mouse = capomulin_df.sample()
mouse_id = list(mouse['Mouse ID'])
mouse_df = clean_df.loc[clean_df['Mouse ID'] == mouse_id[0]].sort_values(by = "Timepoint", ascending = True)

# Create your plot
fig, ax =plt.subplots()
ax.plot(mouse_df['Timepoint'], mouse_df['Tumor Volume (mm3)'], color="sienna")

# Set labels and other specifics
ax.set_title(f"Mouse Tumor Volume of {mouse_id[0]} over Time for Capomulin Treatment")
ax.set_ylabel("Tumor Volume (mm3)")
ax.set_xlabel("Timepoints")
plt.grid()
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# Again, generate the capomulin dataframe.
all_capomulin_df = capomulin_df.groupby(['Mouse ID'])

# Find averages for volume and weight
avg_tum = all_capomulin_df['Tumor Volume (mm3)'].mean()
avg_weight = all_capomulin_df['Weight (g)'].mean()

# Create your plot
plt.scatter(avg_tum, avg_weight, marker="o", alpha=0.5, c="green", edgecolors="black", s=tumor*3)

# Set labels and other specifics
plt.suptitle("Capomulin Avg. Tumor vs Avg. Mouse Weight")
plt.xlabel("Tumor Volume (mm3)")
plt.ylabel("Mouse Weight (g)")
plt.grid()
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

# Calculcate correlation coefficient
corr=round(sts.pearsonr(avg_tum,avg_weight)[0],2)
print(f"The pearson's correlation coefficient is {corr}")

slope, int, r, p, std_err = sts.linregress(avg_tum, avg_weight)
fit = slope * avg_tum + int
plt.scatter(avg_tum, avg_weight, s=tumor*3, c="magenta", edgecolors="black")
plt.plot(avg_tum, fit, "--")
plt.suptitle('Linear Regression of Mouse Weight vs Average Tumor Volume for Capomulin Regimen')
plt.xlabel('Average Tumor Volume (mm3)')
plt.ylabel('Mouse Weight (g)')
plt.grid()
plt.show()
# Out:
# The pearson's correlation coefficient is 0.84
